# %%
import numpy as np
import tensorflow as tf

# %%
np_array=tf.constant(np.array([1,2,3,4]))
np_array
# Out:
# <tf.Tensor: shape=(4,), dtype=int64, numpy=array([1, 2, 3, 4])>

# %%
t_1d=tf.constant([[1,2,3],[3,4,5]])
t_1d
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [3, 4, 5]], dtype=int32)>

# %%
np_2d_1=tf.constant([1,2,3,4],shape=(2,2))
np_2d_1
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
np_2d_1=tf.constant([1,2,3,4],shape=(2,2),dtype="int64")
np_2d_1
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int64, numpy=
# array([[1, 2],
#        [3, 4]])>

# %%
np_2d_1=tf.constant([1,2,3,4],shape=(2,2),dtype="float32")
np_2d_1
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 2.],
#        [3., 4.]], dtype=float32)>

# %%
np_3d_1=tf.constant([[[1,2],[3,4],[5,6]]],dtype="float32")
np_3d_1
# Out:
# <tf.Tensor: shape=(1, 3, 2), dtype=float32, numpy=
# array([[[1., 2.],
#         [3., 4.],
#         [5., 6.]]], dtype=float32)>

# %%
# type of constant
type(np_3d_1)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
# shape of constant
np_3d_1.shape
# Out:
# TensorShape([1, 3, 2])

# %%
#access constant value
t_1d.numpy()
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]], dtype=int32)

# %%
# c0onstant datatype
t_1d.dtype
# Out:
# tf.int32

# %%
# ham tensor flow conastant me mix value nahi de sakte ,
# agar hum esme mix value dete h to vo hame error dega
# tf.constant([1,23.2,"hello"])
