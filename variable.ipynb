# %%
#variable: variables allows us to add new trainable parammeter to graph
# tf.variable()

# %%
import tensorflow as tf

# %%
#create tensor
tf.Variable(1)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=1>

# %%
a=tf.Variable([1,2,3,4])
a
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
a.name
# Out:
# 'Variable:0'

# %%
a.shape
# Out:
# TensorShape([4])

# %%
a.dtype
# Out:
# tf.int32

# %%
a.numpy()
# Out:
# array([1, 2, 3, 4], dtype=int32)

# %%
type(a)
# Out:
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %%
# Create TF using Integer , Float , String , Bool , Complex Number
t_f=tf.Variable([1.2,4.4,5,6])
t_f

# Create tr using constant tensorflow variable
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=float32, numpy=array([1.2, 4.4, 5. , 6. ], dtype=float32)>

# %%
t_s=tf.Variable(['a','b','c','d'])
t_s
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=string, numpy=array([b'a', b'b', b'c', b'd'], dtype=object)>

# %%
t_f=tf.Variable([True,False])
t_f
# Out:
# <tf.Variable 'Variable:0' shape=(2,) dtype=bool, numpy=array([ True, False])>

# %%
# python me jab ham complex number banate h to 'i' ki jagah per 'j'  ka use karte h
t_cx=tf.Variable([3+4j])
t_cx
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=complex128, numpy=array([3.+4.j])>

# %%
# Create TF from Constant TensorFlow Variable

# %%
t_con=tf.constant([1,2,3,4])
t_con
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
t_v=tf.Variable(t_con)
t_v
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
#create tf variable with different shape
t_2d=tf.Variable([[2,3],[4,5]])
t_2d
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=int32, numpy=
# array([[2, 3],
#        [4, 5]], dtype=int32)>

# %%
t_2d=tf.Variable([[2,3],[4,5]],shape=(2,2) , dtype='float32')
t_2d
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[2., 3.],
#        [4., 5.]], dtype=float32)>

# %%
#reshape variable
a=tf.reshape(a,(2,2))
a
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
a
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
# Get index of highest value

t_2d
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[2., 3.],
#        [4., 5.]], dtype=float32)>

# %%
tf.argmax(t_2d)
# Out:
# <tf.Tensor: shape=(2,), dtype=int64, numpy=array([1, 1])>

# %%
tf.argmax(t_2d).numpy()
# Out:
# array([1, 1])

# %%
# Viewed/ Convert as a tensor



a=tf.Variable([1,2,3,4])
a
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
tf.convert_to_tensor(a)
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
tf.convert_to_tensor(t_2d)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[2., 3.],
#        [4., 5.]], dtype=float32)>

# %%
# Change and assign new value to tensor

a
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
a.assign([3,4,5,6]) # yaha per hamarea data replace hota h
# Out:
# <tf.Variable 'UnreadVariable' shape=(4,) dtype=int32, numpy=array([3, 4, 5, 6], dtype=int32)>

# %%
# Assign variable with another memory


a
# Out:
# <tf.Variable 'Variable:0' shape=(4,) dtype=int32, numpy=array([3, 4, 5, 6], dtype=int32)>

# %%
a.assign_add([4,5,6,7])
# Out:
# <tf.Variable 'UnreadVariable' shape=(4,) dtype=int32, numpy=array([ 7,  9, 11, 13], dtype=int32)>

# %%
a.assign_sub([1,2,3,4])
# Out:
# <tf.Variable 'UnreadVariable' shape=(4,) dtype=int32, numpy=array([6, 7, 8, 9], dtype=int32)>

# %%
#Can't change the shape


# a.assign([2,3,4,5,2])

# %%
#Can't change the type


# a.assign([2.1,3.3,4.5,5.1,2.5])
